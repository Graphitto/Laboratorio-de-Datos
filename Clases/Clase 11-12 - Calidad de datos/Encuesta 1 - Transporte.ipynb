# %%
import pandas as pd

archivo = 'Materiales/Clase 11 resultados.csv'
df = pd.read_csv(archivo)

# %%
list(df.columns)
# Out:
# ['Marca temporal',
#  'Dirección de correo electrónico',
#  'Estudiante',
#  'Sexo',
#  'Fecha de Nacimiento',
#  'Localidad',
#  'Provincia',
#  'Transporte',
#  'Tamaño del calzado']

# %%
# A) ¿Cuántos estudiantes respondieron?

df.shape[0]
# Out:
# 49

# %%
# B) ¿Cuántos estudiantes eran en total? -- 50

# %%
# C) ¿Hubo estudiantes que respondieron varias veces? (mail repetido)

len(df['Dirección de correo electrónico']) == 49
# Out:
# True

# %%
# D) ¿Transporte más utilizado?

df['Transporte'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Transporte'>

# %%
# E)

# %%
df_denguezika = pd.read_excel('Materiales/Dengue Zika 2020.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\test_env\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\anaconda3\envs\test_env\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df_tp1 = pd.read_csv('Materiales/datos_migraciones.csv')

df_tp1['Country Origin Name'].str.lower().unique().shape[0]
# Out:
# 232

# %%
# list(df_tp1['Country Origin Name'].str.lower().unique()) # Country Origin Name
# len(list(df_tp1['Country Origin Code'].str.lower().unique())) # Country Origin Code
len(list(df_tp1['Country Dest Name'].str.lower().unique())) # Country Dest Name
# len(list(df_tp1['Country Dest Code'].str.lower().unique())) # Country Dest Code
# Out:
# 231
